 Decimal('0.4526865482330322265625'),
 Decimal('1.4726717472076416015625'),
 Decimal('0.55329418182373046875'),
 Decimal('1.9211394786834716796875'),
 Decimal('0.642501354217529296875'),
 Decimal('1.4123208522796630859375'),
 Decimal('1.342214107513427734375'),
 Decimal('1.125082969665527343750'),
 Decimal('0.771714687347412109375'),
 Decimal('0.4652812480926513671875'),
 Decimal('1.4122016429901123046875'),
 Decimal('1.3588967323303222656250'),
 Decimal('1.4961795806884765625000'),
 Decimal('1.237191200256347656250'),
 Decimal('0.6329314708709716796875'),
 Decimal('0.56477832794189453125'),
 Decimal('0.2313878536224365234375'),
 Decimal('1.4742271900177001953125'),
 Decimal('0.5617249011993408203125'),
 Decimal('1.04777908325195312500'),
 Decimal('1.0853590965270996093750'),
 Decimal('1.146777629852294921875'),
 Decimal('1.1319611072540283203125'),
 Decimal('1.7797985076904296875000'),
 Decimal('0.878676414489746093750'),
 Decimal('0.6164190769195556640625'),
 Decimal('1.1864619255065917968750'),
 Decimal('0.1296823024749755859375'),
 Decimal('0.8267667293548583984375'),
 Decimal('1.3380587100982666015625'),
 Decimal('0.1761028766632080078125'),
 Decimal('1.3936784267425537109375'),
 Decimal('0.3753454685211181640625'),
 Decimal('0.2534780502319335937500'),
 Decimal('1.9910404682159423828125'),
 Decimal('1.0293941497802734375'),
 Decimal('0.5775902271270751953125'),
 Decimal('0.6542465686798095703125'),
 Decimal('0.1075885295867919921875'),
 Decimal('1.0755982398986816406250'),
 Decimal('0.0683848857879638671875'),
 Decimal('0.7973256111145019531250'),
 Decimal('0.9410390853881835937500'),
 Decimal('0.6848568916320800781250'),
 Decimal('0.70013999938964843750'),
 Decimal('0.768395423889160156250'),
 Decimal('0.2076065540313720703125'),
 Decimal('0.7337987422943115234375'),
 Decimal('0.951876163482666015625'),
 Decimal('0.4232525825500488281250'),
 Decimal('0.21253395080566406250'),
 Decimal('0.6409504413604736328125'),
 Decimal('0.2500290870666503906250'),
 Decimal('0.2141396999359130859375'),
 Decimal('0.8261542320251464843750'),
 Decimal('0.6875848770141601562500'),
 Decimal('0.9832448959350585937500'),
 Decimal('0.9321930408477783203125'),
 Decimal('1.1248822212219238281250'),
 Decimal('0.9384396076202392578125'),
 Decimal('0.9703524112701416015625'),
 Decimal('0.9546930789947509765625')]

cliques_len = [7,
 499,
 9,
 6,
 6,
 7,
 12,
 4254,
 3553,
 1546,
 1338,
 2993,
 2823,
 1538,
 3576,
 272,
 2317,
 2957,
 1529,
 359,
 3086,
 1197,
 3505,
 623,
 652,
 3532,
 3629,
 1482,
 3626,
 551,
 3603,
 4144,
 1682,
 331,
 2905,
 2205,
 528,
 2749,
 3017,
 3333,
 1693,
 650,
 2191,
 3637,
 195,
 1977,
 2973,
 1347,
 4551,
 1495,
 3848,
 2914,
 2743,
 1981,
 1000,
 3367,
 3596,
 3327,
 3068,
 1755,
 1275,
 659,
 3524,
 1532,
 2342,
 2101,
 2837,
 2777,
 4097,
 2153,
 1803,
 3056,
 337,
 1433,
 2866,
 404,
 3331,
 670,
 467,
 4553,
 2588,
 2412,
 2868,
 453,
 3910,
 268,
 3462,
 4179,
 2991,
 3002,
 3296,
 892,
 3173,
 4105,
 1852,
 918,
 2777,
 1100,
 926,
 3482,
 3001,
 4251,
 3466,
 4026,
 4102,
 4135,
 4015]

# %%
zipped_pairs_g = zip(cliques_len, time_g)
zipped_pairs_ilp = zip(cliques_len, time_ilp)
sorted_time_g = [x for _, x in sorted(zipped_pairs_g)]
cliques_len_sorted = sorted(cliques_len)
sorted_time_ilp = [x for _, x in sorted(zipped_pairs_ilp)]

# %%
len(cliques_len_sorted)
# Out:
# 107

# %%
figure = plt.figure()
figure.set_figwidth(20)
figure.set_figheight(10)
plt.plot(cliques_len_sorted, sorted_time_g, color='red')
plt.plot(cliques_len_sorted, sorted_time_ilp, color='green')
plt.xlabel("Number of Cliques", fontsize="large")
plt.ylabel("Execution Time in seconds", fontsize="large")
plt.legend(["DSatur","ILP"], loc="upper left")
plt.title("Number of Cliques vs. Execution Time", fontsize="large")
plt.show()

# %%
figure = plt.figure()
figure.set_figwidth(20)
figure.set_figheight(10)
plt.plot(cliques_len_sorted[:20], sorted_time_g[:20], color='red')
plt.plot(cliques_len_sorted[:20], sorted_time_ilp[:20], color='green')
plt.xlabel("Number of Cliques", fontsize="large")
plt.ylabel("Execution Time in seconds", fontsize="large")
plt.legend(["DSatur","ILP"], loc="upper left")
plt.title("Number of Cliques vs. Execution Time (Small number of cliques)", fontsize="large")
plt.show()

# %%
figure = plt.figure()
figure.set_figwidth(20)
figure.set_figheight(10)
plt.plot(cliques_len_sorted[20:100], sorted_time_g[20:100], color='red')
plt.plot(cliques_len_sorted[20:100], sorted_time_ilp[20:100], color='green')
plt.xlabel("Number of Cliques", fontsize="large")
plt.ylabel("Execution Time in seconds ", fontsize="large")
plt.legend(["DSatur","ILP"], loc="upper left")
plt.title("Number of Cliques vs. Execution Time (Medium Number of cliques)", fontsize="large")
plt.show()

# %%
figure = plt.figure()
figure.set_figwidth(20)
figure.set_figheight(10)
plt.plot(cliques_len_sorted[100:], sorted_time_g[100:], color='red')
plt.plot(cliques_len_sorted[100:], sorted_time_ilp[100:], color='green')
plt.xlabel("Number of Cliques", fontsize="large")
plt.ylabel("Execution Time in seconds", fontsize="large")
plt.legend(["DSatur","ILP"], loc="upper left")
plt.title("Number of Cliques vs. Execution Time (Large number of cliques)", fontsize="large")
plt.show()

# %%
with open('output.csv', "w+") as f:
    header = 'Number of Cliques, Execution Time(Greedy), Execution Time(ILP)'
    f.write(header)
    f.write("\n")
    for i in range(len(cliques_len_sorted)):
        f.write(f"{cliques_len_sorted[i]},{sorted_time_g[i]}, {sorted_time_ilp[i]}")
        f.write("\n")
